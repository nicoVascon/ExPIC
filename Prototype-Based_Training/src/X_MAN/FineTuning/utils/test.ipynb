# %%
from PIL import Image
from CMMD_preprocessing import preprocess_image
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import time

img_path = "/nfs/home/nvasconcellos.it/softLinkTests/X-MAN/Prototype-Based_Training/src/X_MAN/FineTuning/utils/115.jpg"

img = Image.open(img_path)
img = np.array(img)
start = time.time()
preprocessed_img = preprocess_image(img, CLAHE_clip_limit=0.005)
end = time.time()
print("Time taken to preprocess the image: ", end-start)
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(img, cmap='gray')
plt.subplot(1, 2, 2)
plt.title("Preprocessed Image")
plt.imshow(preprocessed_img, cmap='gray')
# Out:
# Threshold:  3
# Time taken to preprocess the image:  2.0827248096466064
